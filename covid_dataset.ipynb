# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('COVID.csv')

# %%
df
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1        2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2        3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3        4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4        5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# ...    ...          ...                                                ...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym                  Status         Study Results  \
# ...

# %%
df.dtypes
# Out:
# Rank                         int64
# NCT Number                  object
# Title                       object
# Acronym                     object
# Status                      object
# Study Results               object
# Conditions                  object
# Interventions               object
# Outcome Measures            object
# Sponsor/Collaborators       object
# Gender                      object
# Age                         object
# Phases                      object
# Enrollment                 float64
# Funded Bys                  object
# Study Type                  object
# Study Designs               object
# Other IDs                   object
# Start Date                  object
# Primary Completion Date     object
# Completion Date             object
# First Posted                object
# Results First Posted        object
# Last Update Posted          object
# Locations                   object
# Study Documents             object
# URL                         object
# ...

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
df[['Start Date','Completion Date']]
# Out:
#              Start Date    Completion Date
# 0      November 9, 2020     April 30, 2021
# 1      November 2, 2020   January 29, 2021
# 2           May 7, 2020      June 15, 2021
# 3          May 25, 2020    August 31, 2020
# 4           May 5, 2020           May 2021
# ...                 ...                ...
# 5778     March 23, 2020         April 2023
# 5779         April 2021      December 2024
# 5780  February 10, 2021          July 2021
# 5781     March 22, 2021  December 31, 2022
# 5782      February 2021      February 2025
#
# [5783 rows x 2 columns]

# %%
df['Locations'].value_counts().head(10).plot(kind='bar',edgecolor='black')
# Out:
# <Axes: xlabel='Locations'>

# %%
location_counts = df['Locations'].value_counts()

plt.figure(figsize=(12,8))
location_counts.head(10).plot(kind='bar',edgecolor='black')
plt.title('Top 10 locations conducting clinical trials')
plt.xlabel('Locations')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Divyansh\AppData\Local\Temp\ipykernel_19096\2953411321.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1        2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2        3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3        4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4        5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# ...    ...          ...                                                ...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym                  Status         Study Results  \
# ...

# %%
df[df['Conditions'].str.contains('cov', case=False)]
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1        2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2        3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3        4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4        5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# ...    ...          ...                                                ...
# 5614  5615  NCT04480333  Safety, Tolerability and Pharmacokinetics of I...
# 5649  5650  NCT03256773                  High Resolution Micro OCT Imaging
# 5682  5683  NCT04326309  Audio Data Collection for Identification and C...
# 5694  5695  NCT04574050        SELF-BREATHE RCT for Chronic Breathlessness
# 5724  5725  NCT03452774  SYNERGY-AI: Artificial Intelligence Based Prec...
#
#            Acronym                  Status         Study Results  \
# ...

# %%
for_plot = df.groupby(df['Conditions'].str.contains('cov', case=False)).size()

# %%
for_plot.plot(kind='line',marker='o')
# Out:
# <Axes: xlabel='Conditions'>

# %%
df['Phases'].value_counts()
# Out:
# Phases
# Not Applicable     1354
# Phase 2             685
# Phase 3             450
# Phase 1             234
# Phase 2|Phase 3     200
# Phase 1|Phase 2     192
# Phase 4             161
# Early Phase 1        46
# Name: count, dtype: int64

# %%
phases_count = df['Phases'].value_counts()

phases_count.plot(kind='bar',edgecolor='black')
# Out:
# <Axes: xlabel='Phases'>

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
df['Conditions'].value_counts()
# Out:
# Conditions
# COVID-19                                                                                                                                    720
# Covid19                                                                                                                                     657
# COVID                                                                                                                                        95
# Covid-19                                                                                                                                     88
# SARS-CoV-2                                                                                                                                   52
#                                                                                                                                            ...
# ...

# %%
df['Conditions'].nunique()
# Out:
# 3067

# %%
np.unique(df['Conditions'])
# Out:
# array(['2019 Novel Coronavirus', '2019 Novel Coronavirus Infection',
#        '2019 Novel Coronavirus Infection|COVID-19 Virus Infection|SARS Coronavirus 2 Infection|SARS-CoV-2 Infection|Respiratory Distress Syndrome, Adult|Adult Respiratory Distress Syndrome',
#        ...,
#        'the Study Focus on the Uses of Telephone and Other New Technology in Medicine, Diagnosis and Treatment',
#        'the Use of Modern Technology Applications in Home Isolation',
#        'to Predict an Unfavorable Evolution of Covid-19 at the Hospital Admission of Patients'],
#       dtype=object)

# %%
df['Status'].value_counts().plot(kind='bar',figsize=(10,8))
# Out:
# <Axes: xlabel='Status'>

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'],errors='coerce')

# %%
df['Completion Date'] = pd.to_datetime(df['Completion Date'],errors='coerce')

# %%
df['Duration'] = (df['Completion Date'] - df['Start Date']).dt.days

# %%
df['Duration']
# Out:
# 0       172.0
# 1        88.0
# 2       404.0
# 3        98.0
# 4         NaN
#         ...
# 5778      NaN
# 5779      NaN
# 5780      NaN
# 5781    649.0
# 5782      NaN
# Name: Duration, Length: 5783, dtype: float64

# %% [markdown]
# average duration of a study

# %%
avg_duration = df['Duration'].mean()

# %%
avg_duration
# Out:
# 402.5419919564703

# %% [markdown]
# studies involving COVID or SARS-CoV2

# %%
covid_studies = df[df['Conditions'].str.contains('COVID|SARS-CoV-2',case=False,na=False)]

# %%
covid_studies.head(5)
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
df['Country'] = df['Locations'].str.extract(r'(\b[A-Z][a-z]+\b)$')

# %%
df['Country']
# Out:
# 0         France
# 1       Colombia
# 2         Marino
# 3           Kong
# 4         France
#           ...
# 5778      States
# 5779     Germany
# 5780      States
# 5781     Denmark
# 5782      States
# Name: Country, Length: 5783, dtype: object

# %% [markdown]
# Last Completion Date

# %%
df['Completion Date'].dropna().sort_values(ascending=True).tail(1)
# Out:
# 4612   2099-12-31
# Name: Completion Date, dtype: datetime64[ns]

# %% [markdown]
# First Completion Date

# %%
df['Completion Date'].dropna().sort_values(ascending=True).head(1)
# Out:
# 5743   2018-05-25
# Name: Completion Date, dtype: datetime64[ns]

# %% [markdown]
# How many studies are conducted in each location given in locations column

# %%
df['Locations'].value_counts().head(5)
# Out:
# Locations
# Uhmontpellier, Montpellier, France                                                  19
# National Institutes of Health Clinical Center, Bethesda, Maryland, United States    16
# Stanford University, Stanford, California, United States                            13
# CHU Amiens, Amiens, France                                                          13
# Massachusetts General Hospital, Boston, Massachusetts, United States                12
# Name: count, dtype: int64
